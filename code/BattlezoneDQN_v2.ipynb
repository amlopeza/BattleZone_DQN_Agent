# %% [markdown]
# # Aprendizaje por refuerzo profundo - Proyecto del curso
# Solución Reto 1 haciendo uso de aprendizaje por refuerzo profundo para el juego Battle Zone
#
# **Docentes**: Fernando Lozano - Nicolás Cardozo
#
# **Estudiantes**:
#
# - Jose Mario Bogotá
#
# - Ana María López Arciniegas
#
# Maestría en Inteligencia Artificial- Universidad de los Andes

# %% [markdown]
# ## Importación de librerias

# %%
# ===============================================
# 🔧 Instalación de dependencias (Colab)
# ===============================================
# Núcleo RL y entornos Atari
# !pip install -q "gymnasium[atari,accept-rom-license]" ale-py autorom
# !pip install -q stable-baselines3 sb3-contrib    # SB3 + algoritmos extra (si los usas)

# Utilidades opcionales
# !pip install -q opencv-python                     # Procesamiento de imágenes/video (opcional)

# Descarga e instalación de ROMs de Atari (requiere autorom instalado)
# !AutoROM --accept-license -v

# ===============================================
# 📦 Imports principales
# ===============================================
import gymnasium as gym
import ale_py
import numpy as np
import matplotlib.pyplot as plt

import stable_baselines3
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.logger import configure, Logger, CSVOutputFormat, HumanOutputFormat
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.env_util import make_atari_env, make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack, VecMonitor, VecVideoRecorder
from gymnasium.wrappers import TimeLimit

# Utilidades
from collections import deque
import cv2
import os, sys, math, random, pandas as pd

# Registrar entornos ALE en Gymnasium (necesario en algunos Colab)
gym.register_envs(ale_py)

# Limpieza de salida tras instalación (estético)
from IPython.display import clear_output
clear_output()
print("✅ Entorno listo: Gymnasium + ALE + SB3 + ROMs de Atari.")
# Out:
# ✅ Entorno listo: Gymnasium + ALE + SB3 + ROMs de Atari.

# %%
def make_dqn_battlezone(env):
    model = DQN(
        policy="CnnPolicy",
        env=env,
        learning_rate=1e-4,
        buffer_size=300_000,
        learning_starts=20_000,
        batch_size=64,
        gamma=0.99,
        target_update_interval=10_000,
        train_freq=4,
        gradient_steps=1,
        exploration_initial_eps=1.0,
        exploration_final_eps=0.02,
        exploration_fraction=0.20,

        verbose=0,
    )
    return model

# %%
# Callback personalizado para registrar las recompensas por episodio durante el entrenamiento
class RewardLoggerCallback(BaseCallback):
    def __init__(self, log_interval=50):
        super().__init__()
        self.episode_rewards = [] # Lista para almacenar las recomprensas por episodio
        self.log_interval = log_interval

    def _on_step(self) -> bool:
        # Verificar si hay información de los episodios en los infos proporcionados por el entorno
        for info in self.locals.get('infos', []):
            if 'episode' in info:
                reward_acu = info['episode']['r']
                self.episode_rewards.append(reward_acu)
                if len(self.episode_rewards) % self.log_interval == 0:
                    avg = np.mean(self.episode_rewards[-self.log_interval:])
                    print(f"[Episodio {len(self.episode_rewards)}]"
                          f"Recompensa promedio últimos episodios {self.log_interval}: {avg:.2f}")
        return True
# Guarda el replay buffer cada N steps
class SaveReplayBufferCallback(BaseCallback):
    def __init__(self, save_path, save_every=200_000):
        super().__init__()
        self.save_path = save_path
        self.save_every = save_every

    def _on_step(self) -> bool:
        if self.num_timesteps % self.save_every == 0:
            self.model.save_replay_buffer(self.save_path)
            print(f"[SB3] Replay buffer guardado en {self.save_path} @ {self.num_timesteps} steps")
        return True


class BattleZoneTrainer:
    def __init__(self, model_fn, total_timesteps=1_000_000, log_dir="./logs_bzone_v2", seed=0, resume_from=None):
        os.makedirs(log_dir, exist_ok=True)
        env = make_atari_env("ALE/BattleZone-v5", n_envs=1, seed=seed)
        env = VecFrameStack(env, n_stack=4)
        env.envs[0] = Monitor(env.envs[0], filename=os.path.join(log_dir, "monitor.csv"))
        self.env = env
        self.log_dir = log_dir

        # ⬇️ Cargar modelo si hay checkpoint, si no crear uno nuevo
        if resume_from and os.path.exists(resume_from):
            print(f"[Resume] Cargando modelo desde {resume_from}")
            self.model = DQN.load(resume_from, env=self.env, device="auto")
            # (Opcional) Cargar replay buffer si existe
            rb_path = os.path.join(log_dir, "replay_buffer.pkl")
            if os.path.exists(rb_path):
                self.model.load_replay_buffer(rb_path)
                print(f"[Resume] Replay buffer cargado desde {rb_path}")
        else:
            self.model = model_fn(self.env)

        self.callback = RewardLoggerCallback()
        self.total_timesteps = total_timesteps


    def train(self, save_path='dqn_battlezone'):
        self.model.learn(
            total_timesteps=self.total_timesteps,
            log_interval=100,
            callback=self.callback,
            reset_num_timesteps=False   # ⬅️ agrega esta línea
        )
        self.model.save(save_path)
        print("Entrenamiento completo, modelo guardado", save_path)



    def plot_rewards(self):
        # Gráfica la evolución de las recompensas por episodio
        if not self.callback.episode_rewards:
            print("No reward data to plot")
            return
        plt.figure(figsize=(10,5))
        plt.plot(self.callback.episode_rewards, label='Recompensa por episodio')
        plt.xlabel('episodios')
        plt.ylabel('Recompensa')
        plt.title("Recompensas - entrenamiento sobre el tiempo")
        plt.grid()
        plt.legend()
        plt.tight_layout()
        plt.show()

    def generate_video(self, model_path="dqn_battlezone_v2.zip", out_dir="./output_v2", seed=0): # modificar max_steps
        os.makedirs(out_dir, exist_ok=True)

        model = DQN.load(model_path)

        # Mismo pipeline que entrenamiento
        env = make_atari_env("ALE/BattleZone-v5", n_envs=1, seed=seed)
        env = VecFrameStack(env, n_stack=4)

        # Envolver con grabador de video
        env = VecVideoRecorder(
            env,
            video_folder=out_dir,
            record_video_trigger=lambda step: step == 0,  # graba desde el inicio
            video_length=1_000_000
        )

        obs = env.reset()
        k = 10
        NOOP = np.array([0], dtype=np.int64)

        for _ in range(k):
            obs, rewards, dones, infos = env.step(NOOP)
            if dones[0]:
                obs = env.reset()

        total_reward = 0.0
        steps = 0

        while True:
            action, _ = model.predict(obs, deterministic=True)
            if not isinstance(action, np.ndarray) or action.ndim == 0:
                action = np.array([int(action)], dtype = np.int64)
            obs, rewards, dones, infos = env.step(action)
            total_reward += float(rewards[0])
            steps += 1
            if dones[0]:
                break

        env.close()

# %%
if __name__ == "__main__":
    # Reanudar desde un checkpoint existente (ajusta la ruta si usaste otra)
    trainer = BattleZoneTrainer(
        model_fn= make_dqn_battlezone,
        total_timesteps=2_000_000,                         # pasos adicionales
        log_dir="./logs_bzone_v2",
        seed=0,
        resume_from="dqn_battlezone.zip"                 # ⬅️ tu checkpoint previo
    )
    trainer.train(save_path="dqn_battlezone_resume.zip")
    trainer.plot_rewards()
    trainer.generate_video(model_path="dqn_battlezone_resume.zip")
# Out:
# /home/amlopeza/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/vec_monitor.py:44: UserWarning: The environment is already wrapped with a `Monitor` wrapperbut you are wrapping it with a `VecMonitor` wrapper, the `Monitor` statistics will beoverwritten by the `VecMonitor` ones.
#   warnings.warn(
# [Resume] Cargando modelo desde dqn_battlezone.zip
# [Episodio 50]Recompensa promedio últimos episodios 50: 2.46
# [Episodio 100]Recompensa promedio últimos episodios 50: 2.40
# [Episodio 150]Recompensa promedio últimos episodios 50: 3.04
# [Episodio 200]Recompensa promedio últimos episodios 50: 2.92
# [Episodio 250]Recompensa promedio últimos episodios 50: 2.68
# [Episodio 300]Recompensa promedio últimos episodios 50: 2.60
# [Episodio 350]Recompensa promedio últimos episodios 50: 2.74
# [Episodio 400]Recompensa promedio últimos episodios 50: 2.94
# [Episodio 450]Recompensa promedio últimos episodios 50: 2.58
# [Episodio 500]Recompensa promedio últimos episodios 50: 3.00
# [Episodio 550]Recompensa promedio últimos episodios 50: 2.88
# [Episodio 600]Recompensa promedio últimos episodios 50: 3.34
# [Episodio 650]Recompensa promedio últimos episodios 50: 3.26
# [Episodio 700]Recompensa promedio últimos episodios 50: 3.58
# [Episodio 750]Recompensa promedio últimos episodios 50: 2.88
# [Episodio 800]Recompensa promedio últimos episodios 50: 2.80
# [Episodio 850]Recompensa promedio últimos episodios 50: 3.36
# [Episodio 900]Recompensa promedio últimos episodios 50: 3.10
# [Episodio 950]Recompensa promedio últimos episodios 50: 2.96
# [Episodio 1000]Recompensa promedio últimos episodios 50: 2.76
# [Episodio 1050]Recompensa promedio últimos episodios 50: 2.96
# [Episodio 1100]Recompensa promedio últimos episodios 50: 3.32
# [Episodio 1150]Recompensa promedio últimos episodios 50: 3.36
# [Episodio 1200]Recompensa promedio últimos episodios 50: 3.34
# [Episodio 1250]Recompensa promedio últimos episodios 50: 3.00
# [Episodio 1300]Recompensa promedio últimos episodios 50: 3.16
# [Episodio 1350]Recompensa promedio últimos episodios 50: 3.34
# [Episodio 1400]Recompensa promedio últimos episodios 50: 3.32
# [Episodio 1450]Recompensa promedio últimos episodios 50: 3.12
# [Episodio 1500]Recompensa promedio últimos episodios 50: 2.94
# [Episodio 1550]Recompensa promedio últimos episodios 50: 3.38
# [Episodio 1600]Recompensa promedio últimos episodios 50: 3.38
# [Episodio 1650]Recompensa promedio últimos episodios 50: 2.86
# [Episodio 1700]Recompensa promedio últimos episodios 50: 3.74
# [Episodio 1750]Recompensa promedio últimos episodios 50: 3.20
# [Episodio 1800]Recompensa promedio últimos episodios 50: 3.26
# [Episodio 1850]Recompensa promedio últimos episodios 50: 3.42
# [Episodio 1900]Recompensa promedio últimos episodios 50: 3.82
# [Episodio 1950]Recompensa promedio últimos episodios 50: 2.88
# [Episodio 2000]Recompensa promedio últimos episodios 50: 3.06
# [Episodio 2050]Recompensa promedio últimos episodios 50: 3.70
# [Episodio 2100]Recompensa promedio últimos episodios 50: 3.30
# [Episodio 2150]Recompensa promedio últimos episodios 50: 3.14
# [Episodio 2200]Recompensa promedio últimos episodios 50: 2.74
# [Episodio 2250]Recompensa promedio últimos episodios 50: 3.00
# [Episodio 2300]Recompensa promedio últimos episodios 50: 3.22
# [Episodio 2350]Recompensa promedio últimos episodios 50: 3.26
# [Episodio 2400]Recompensa promedio últimos episodios 50: 3.86
# [Episodio 2450]Recompensa promedio últimos episodios 50: 2.86
# [Episodio 2500]Recompensa promedio últimos episodios 50: 3.82
# [Episodio 2550]Recompensa promedio últimos episodios 50: 3.40
# [Episodio 2600]Recompensa promedio últimos episodios 50: 3.40
# [Episodio 2650]Recompensa promedio últimos episodios 50: 3.42
# [Episodio 2700]Recompensa promedio últimos episodios 50: 2.70
# [Episodio 2750]Recompensa promedio últimos episodios 50: 3.32
# [Episodio 2800]Recompensa promedio últimos episodios 50: 3.38
# [Episodio 2850]Recompensa promedio últimos episodios 50: 2.90
# [Episodio 2900]Recompensa promedio últimos episodios 50: 3.42
# [Episodio 2950]Recompensa promedio últimos episodios 50: 2.94
# [Episodio 3000]Recompensa promedio últimos episodios 50: 2.80
# [Episodio 3050]Recompensa promedio últimos episodios 50: 2.94
# [Episodio 3100]Recompensa promedio últimos episodios 50: 3.24
# [Episodio 3150]Recompensa promedio últimos episodios 50: 3.18
# [Episodio 3200]Recompensa promedio últimos episodios 50: 2.86
# [Episodio 3250]Recompensa promedio últimos episodios 50: 3.20
# [Episodio 3300]Recompensa promedio últimos episodios 50: 3.60
# [Episodio 3350]Recompensa promedio últimos episodios 50: 3.60
# [Episodio 3400]Recompensa promedio últimos episodios 50: 3.54
# [Episodio 3450]Recompensa promedio últimos episodios 50: 3.94
# [Episodio 3500]Recompensa promedio últimos episodios 50: 3.80
# [Episodio 3550]Recompensa promedio últimos episodios 50: 3.66
# [Episodio 3600]Recompensa promedio últimos episodios 50: 3.52
# [Episodio 3650]Recompensa promedio últimos episodios 50: 3.46
# [Episodio 3700]Recompensa promedio últimos episodios 50: 4.16
# [Episodio 3750]Recompensa promedio últimos episodios 50: 3.94
# [Episodio 3800]Recompensa promedio últimos episodios 50: 3.80
# [Episodio 3850]Recompensa promedio últimos episodios 50: 3.80
# [Episodio 3900]Recompensa promedio últimos episodios 50: 3.74
# [Episodio 3950]Recompensa promedio últimos episodios 50: 3.66
# [Episodio 4000]Recompensa promedio últimos episodios 50: 3.68
# [Episodio 4050]Recompensa promedio últimos episodios 50: 3.94
# [Episodio 4100]Recompensa promedio últimos episodios 50: 4.54
# [Episodio 4150]Recompensa promedio últimos episodios 50: 3.28
# [Episodio 4200]Recompensa promedio últimos episodios 50: 4.10
# [Episodio 4250]Recompensa promedio últimos episodios 50: 3.64
# [Episodio 4300]Recompensa promedio últimos episodios 50: 4.52
# [Episodio 4350]Recompensa promedio últimos episodios 50: 4.36
# [Episodio 4400]Recompensa promedio últimos episodios 50: 4.50
# [Episodio 4450]Recompensa promedio últimos episodios 50: 3.64
# [Episodio 4500]Recompensa promedio últimos episodios 50: 3.82
# [Episodio 4550]Recompensa promedio últimos episodios 50: 4.18
# [Episodio 4600]Recompensa promedio últimos episodios 50: 4.08
# [Episodio 4650]Recompensa promedio últimos episodios 50: 3.76
# [Episodio 4700]Recompensa promedio últimos episodios 50: 4.66
# [Episodio 4750]Recompensa promedio últimos episodios 50: 3.88
# [Episodio 4800]Recompensa promedio últimos episodios 50: 4.18
# [Episodio 4850]Recompensa promedio últimos episodios 50: 3.72
# [Episodio 4900]Recompensa promedio últimos episodios 50: 4.04
# [Episodio 4950]Recompensa promedio últimos episodios 50: 3.56
# [Episodio 5000]Recompensa promedio últimos episodios 50: 3.46
# [Episodio 5050]Recompensa promedio últimos episodios 50: 3.92
# [Episodio 5100]Recompensa promedio últimos episodios 50: 3.98
# [Episodio 5150]Recompensa promedio últimos episodios 50: 3.50
# [Episodio 5200]Recompensa promedio últimos episodios 50: 4.10
# [Episodio 5250]Recompensa promedio últimos episodios 50: 4.64
# [Episodio 5300]Recompensa promedio últimos episodios 50: 4.24
# [Episodio 5350]Recompensa promedio últimos episodios 50: 4.58
# [Episodio 5400]Recompensa promedio últimos episodios 50: 4.36
# [Episodio 5450]Recompensa promedio últimos episodios 50: 3.66
# [Episodio 5500]Recompensa promedio últimos episodios 50: 4.46
# [Episodio 5550]Recompensa promedio últimos episodios 50: 4.60
# [Episodio 5600]Recompensa promedio últimos episodios 50: 4.24
# [Episodio 5650]Recompensa promedio últimos episodios 50: 4.18
# [Episodio 5700]Recompensa promedio últimos episodios 50: 3.66
# [Episodio 5750]Recompensa promedio últimos episodios 50: 4.10
# [Episodio 5800]Recompensa promedio últimos episodios 50: 3.52
# [Episodio 5850]Recompensa promedio últimos episodios 50: 3.68
# [Episodio 5900]Recompensa promedio últimos episodios 50: 4.50
# [Episodio 5950]Recompensa promedio últimos episodios 50: 3.64
# [Episodio 6000]Recompensa promedio últimos episodios 50: 2.70
# [Episodio 6050]Recompensa promedio últimos episodios 50: 3.58
# [Episodio 6100]Recompensa promedio últimos episodios 50: 3.86
# [Episodio 6150]Recompensa promedio últimos episodios 50: 4.08
# [Episodio 6200]Recompensa promedio últimos episodios 50: 3.58
# [Episodio 6250]Recompensa promedio últimos episodios 50: 3.84
# [Episodio 6300]Recompensa promedio últimos episodios 50: 3.74
# [Episodio 6350]Recompensa promedio últimos episodios 50: 3.78
# [Episodio 6400]Recompensa promedio últimos episodios 50: 3.52
# [Episodio 6450]Recompensa promedio últimos episodios 50: 4.24
# [Episodio 6500]Recompensa promedio últimos episodios 50: 4.24
# [Episodio 6550]Recompensa promedio últimos episodios 50: 4.00
# [Episodio 6600]Recompensa promedio últimos episodios 50: 3.62
# [Episodio 6650]Recompensa promedio últimos episodios 50: 4.42
# [Episodio 6700]Recompensa promedio últimos episodios 50: 3.60
# [Episodio 6750]Recompensa promedio últimos episodios 50: 3.64
# [Episodio 6800]Recompensa promedio últimos episodios 50: 4.00
# [Episodio 6850]Recompensa promedio últimos episodios 50: 4.12
# [Episodio 6900]Recompensa promedio últimos episodios 50: 4.46
# [Episodio 6950]Recompensa promedio últimos episodios 50: 3.94
# [Episodio 7000]Recompensa promedio últimos episodios 50: 4.40
# [Episodio 7050]Recompensa promedio últimos episodios 50: 4.06
# [Episodio 7100]Recompensa promedio últimos episodios 50: 4.76
# [Episodio 7150]Recompensa promedio últimos episodios 50: 3.76
# [Episodio 7200]Recompensa promedio últimos episodios 50: 4.42
# [Episodio 7250]Recompensa promedio últimos episodios 50: 4.94
# [Episodio 7300]Recompensa promedio últimos episodios 50: 4.30
# [Episodio 7350]Recompensa promedio últimos episodios 50: 3.66
# [Episodio 7400]Recompensa promedio últimos episodios 50: 3.84
# [Episodio 7450]Recompensa promedio últimos episodios 50: 4.76
# [Episodio 7500]Recompensa promedio últimos episodios 50: 4.60
# [Episodio 7550]Recompensa promedio últimos episodios 50: 4.26
# [Episodio 7600]Recompensa promedio últimos episodios 50: 5.04
# [Episodio 7650]Recompensa promedio últimos episodios 50: 4.66
# [Episodio 7700]Recompensa promedio últimos episodios 50: 4.28
# [Episodio 7750]Recompensa promedio últimos episodios 50: 4.28
# [Episodio 7800]Recompensa promedio últimos episodios 50: 4.96
# [Episodio 7850]Recompensa promedio últimos episodios 50: 4.44
# [Episodio 7900]Recompensa promedio últimos episodios 50: 3.96
# [Episodio 7950]Recompensa promedio últimos episodios 50: 3.72
# [Episodio 8000]Recompensa promedio últimos episodios 50: 4.46
# [Episodio 8050]Recompensa promedio últimos episodios 50: 4.54
# [Episodio 8100]Recompensa promedio últimos episodios 50: 4.00
# [Episodio 8150]Recompensa promedio últimos episodios 50: 4.10
# [Episodio 8200]Recompensa promedio últimos episodios 50: 4.16
# [Episodio 8250]Recompensa promedio últimos episodios 50: 4.10
# [Episodio 8300]Recompensa promedio últimos episodios 50: 4.00
# [Episodio 8350]Recompensa promedio últimos episodios 50: 3.36
# [Episodio 8400]Recompensa promedio últimos episodios 50: 4.56
# [Episodio 8450]Recompensa promedio últimos episodios 50: 4.80
# [Episodio 8500]Recompensa promedio últimos episodios 50: 4.00
# [Episodio 8550]Recompensa promedio últimos episodios 50: 4.18
# [Episodio 8600]Recompensa promedio últimos episodios 50: 4.12
# [Episodio 8650]Recompensa promedio últimos episodios 50: 4.76
# [Episodio 8700]Recompensa promedio últimos episodios 50: 4.08
# [Episodio 8750]Recompensa promedio últimos episodios 50: 3.60
# [Episodio 8800]Recompensa promedio últimos episodios 50: 4.46
# [Episodio 8850]Recompensa promedio últimos episodios 50: 3.98
# [Episodio 8900]Recompensa promedio últimos episodios 50: 4.18
# [Episodio 8950]Recompensa promedio últimos episodios 50: 4.74
# [Episodio 9000]Recompensa promedio últimos episodios 50: 4.70
# [Episodio 9050]Recompensa promedio últimos episodios 50: 4.34
# [Episodio 9100]Recompensa promedio últimos episodios 50: 4.58
# [Episodio 9150]Recompensa promedio últimos episodios 50: 4.02
# [Episodio 9200]Recompensa promedio últimos episodios 50: 3.48
# [Episodio 9250]Recompensa promedio últimos episodios 50: 3.58
# [Episodio 9300]Recompensa promedio últimos episodios 50: 3.76
# [Episodio 9350]Recompensa promedio últimos episodios 50: 3.82
# [Episodio 9400]Recompensa promedio últimos episodios 50: 3.60
# [Episodio 9450]Recompensa promedio últimos episodios 50: 3.68
# [Episodio 9500]Recompensa promedio últimos episodios 50: 3.74
# [Episodio 9550]Recompensa promedio últimos episodios 50: 4.88
# [Episodio 9600]Recompensa promedio últimos episodios 50: 3.78
# [Episodio 9650]Recompensa promedio últimos episodios 50: 4.50
# [Episodio 9700]Recompensa promedio últimos episodios 50: 4.14
# [Episodio 9750]Recompensa promedio últimos episodios 50: 3.86
# [Episodio 9800]Recompensa promedio últimos episodios 50: 4.80
# [Episodio 9850]Recompensa promedio últimos episodios 50: 3.66
# [Episodio 9900]Recompensa promedio últimos episodios 50: 4.80
# [Episodio 9950]Recompensa promedio últimos episodios 50: 4.78
# [Episodio 10000]Recompensa promedio últimos episodios 50: 3.64
# [Episodio 10050]Recompensa promedio últimos episodios 50: 3.66
# [Episodio 10100]Recompensa promedio últimos episodios 50: 4.50
# [Episodio 10150]Recompensa promedio últimos episodios 50: 4.42
# [Episodio 10200]Recompensa promedio últimos episodios 50: 3.92
# [Episodio 10250]Recompensa promedio últimos episodios 50: 4.60
# [Episodio 10300]Recompensa promedio últimos episodios 50: 4.52
# [Episodio 10350]Recompensa promedio últimos episodios 50: 3.50
# [Episodio 10400]Recompensa promedio últimos episodios 50: 3.76
# [Episodio 10450]Recompensa promedio últimos episodios 50: 4.08
# [Episodio 10500]Recompensa promedio últimos episodios 50: 4.20
# [Episodio 10550]Recompensa promedio últimos episodios 50: 3.86
# [Episodio 10600]Recompensa promedio últimos episodios 50: 4.06
# [Episodio 10650]Recompensa promedio últimos episodios 50: 3.60
# [Episodio 10700]Recompensa promedio últimos episodios 50: 4.54
# [Episodio 10750]Recompensa promedio últimos episodios 50: 4.04
# [Episodio 10800]Recompensa promedio últimos episodios 50: 4.16
# [Episodio 10850]Recompensa promedio últimos episodios 50: 4.26
# [Episodio 10900]Recompensa promedio últimos episodios 50: 3.98
# [Episodio 10950]Recompensa promedio últimos episodios 50: 3.90
# [Episodio 11000]Recompensa promedio últimos episodios 50: 3.80
# [Episodio 11050]Recompensa promedio últimos episodios 50: 3.52
# [Episodio 11100]Recompensa promedio últimos episodios 50: 3.56
# [Episodio 11150]Recompensa promedio últimos episodios 50: 3.78
# [Episodio 11200]Recompensa promedio últimos episodios 50: 3.68
# [Episodio 11250]Recompensa promedio últimos episodios 50: 4.48
# [Episodio 11300]Recompensa promedio últimos episodios 50: 3.60
# [Episodio 11350]Recompensa promedio últimos episodios 50: 4.22
# [Episodio 11400]Recompensa promedio últimos episodios 50: 4.20
# [Episodio 11450]Recompensa promedio últimos episodios 50: 4.96
# [Episodio 11500]Recompensa promedio últimos episodios 50: 3.62
# [Episodio 11550]Recompensa promedio últimos episodios 50: 4.76
# [Episodio 11600]Recompensa promedio últimos episodios 50: 4.94
# [Episodio 11650]Recompensa promedio últimos episodios 50: 4.98
# [Episodio 11700]Recompensa promedio últimos episodios 50: 4.44
# [Episodio 11750]Recompensa promedio últimos episodios 50: 5.56
# [Episodio 11800]Recompensa promedio últimos episodios 50: 4.16
# [Episodio 11850]Recompensa promedio últimos episodios 50: 4.92
# [Episodio 11900]Recompensa promedio últimos episodios 50: 4.64
# [Episodio 11950]Recompensa promedio últimos episodios 50: 4.34
# [Episodio 12000]Recompensa promedio últimos episodios 50: 4.62
# [Episodio 12050]Recompensa promedio últimos episodios 50: 3.96
# [Episodio 12100]Recompensa promedio últimos episodios 50: 4.18
# [Episodio 12150]Recompensa promedio últimos episodios 50: 4.68
# [Episodio 12200]Recompensa promedio últimos episodios 50: 5.06
# [Episodio 12250]Recompensa promedio últimos episodios 50: 4.24
# [Episodio 12300]Recompensa promedio últimos episodios 50: 3.62
# [Episodio 12350]Recompensa promedio últimos episodios 50: 4.54
# [Episodio 12400]Recompensa promedio últimos episodios 50: 4.10
# [Episodio 12450]Recompensa promedio últimos episodios 50: 3.90
# [Episodio 12500]Recompensa promedio últimos episodios 50: 4.04
# [Episodio 12550]Recompensa promedio últimos episodios 50: 4.42
# [Episodio 12600]Recompensa promedio últimos episodios 50: 4.18
# [Episodio 12650]Recompensa promedio últimos episodios 50: 4.28
# [Episodio 12700]Recompensa promedio últimos episodios 50: 4.02
# [Episodio 12750]Recompensa promedio últimos episodios 50: 3.86
# [Episodio 12800]Recompensa promedio últimos episodios 50: 4.60
# [Episodio 12850]Recompensa promedio últimos episodios 50: 5.12
# [Episodio 12900]Recompensa promedio últimos episodios 50: 4.54
# [Episodio 12950]Recompensa promedio últimos episodios 50: 5.24
# [Episodio 13000]Recompensa promedio últimos episodios 50: 4.84
# [Episodio 13050]Recompensa promedio últimos episodios 50: 4.68
# [Episodio 13100]Recompensa promedio últimos episodios 50: 4.44
# [Episodio 13150]Recompensa promedio últimos episodios 50: 4.18
# [Episodio 13200]Recompensa promedio últimos episodios 50: 4.60
# [Episodio 13250]Recompensa promedio últimos episodios 50: 4.32
# [Episodio 13300]Recompensa promedio últimos episodios 50: 3.86
# [Episodio 13350]Recompensa promedio últimos episodios 50: 4.66
# [Episodio 13400]Recompensa promedio últimos episodios 50: 3.94
# [Episodio 13450]Recompensa promedio últimos episodios 50: 4.10
# [Episodio 13500]Recompensa promedio últimos episodios 50: 4.90
# [Episodio 13550]Recompensa promedio últimos episodios 50: 4.16
# [Episodio 13600]Recompensa promedio últimos episodios 50: 4.50
# [Episodio 13650]Recompensa promedio últimos episodios 50: 4.58
# [Episodio 13700]Recompensa promedio últimos episodios 50: 4.48
# [Episodio 13750]Recompensa promedio últimos episodios 50: 4.28
# [Episodio 13800]Recompensa promedio últimos episodios 50: 4.02
# [Episodio 13850]Recompensa promedio últimos episodios 50: 3.86
# [Episodio 13900]Recompensa promedio últimos episodios 50: 4.06
# [Episodio 13950]Recompensa promedio últimos episodios 50: 3.32
# [Episodio 14000]Recompensa promedio últimos episodios 50: 3.94
# [Episodio 14050]Recompensa promedio últimos episodios 50: 3.82
# [Episodio 14100]Recompensa promedio últimos episodios 50: 4.52
# [Episodio 14150]Recompensa promedio últimos episodios 50: 4.74
# [Episodio 14200]Recompensa promedio últimos episodios 50: 5.64
# [Episodio 14250]Recompensa promedio últimos episodios 50: 3.96
# [Episodio 14300]Recompensa promedio últimos episodios 50: 3.40
# [Episodio 14350]Recompensa promedio últimos episodios 50: 4.44
# [Episodio 14400]Recompensa promedio últimos episodios 50: 4.68
# [Episodio 14450]Recompensa promedio últimos episodios 50: 4.98
# [Episodio 14500]Recompensa promedio últimos episodios 50: 4.20
# [Episodio 14550]Recompensa promedio últimos episodios 50: 4.84
# [Episodio 14600]Recompensa promedio últimos episodios 50: 4.10
# [Episodio 14650]Recompensa promedio últimos episodios 50: 4.82
# [Episodio 14700]Recompensa promedio últimos episodios 50: 5.04
# [Episodio 14750]Recompensa promedio últimos episodios 50: 4.52
# [Episodio 14800]Recompensa promedio últimos episodios 50: 3.96
# [Episodio 14850]Recompensa promedio últimos episodios 50: 4.68
# [Episodio 14900]Recompensa promedio últimos episodios 50: 4.62
# [Episodio 14950]Recompensa promedio últimos episodios 50: 4.70
# [Episodio 15000]Recompensa promedio últimos episodios 50: 4.34
# [Episodio 15050]Recompensa promedio últimos episodios 50: 4.36
# [Episodio 15100]Recompensa promedio últimos episodios 50: 4.80
# [Episodio 15150]Recompensa promedio últimos episodios 50: 3.62
# [Episodio 15200]Recompensa promedio últimos episodios 50: 3.96
# [Episodio 15250]Recompensa promedio últimos episodios 50: 4.82
# [Episodio 15300]Recompensa promedio últimos episodios 50: 4.62
# [Episodio 15350]Recompensa promedio últimos episodios 50: 4.80
# [Episodio 15400]Recompensa promedio últimos episodios 50: 4.22
# [Episodio 15450]Recompensa promedio últimos episodios 50: 3.64
# [Episodio 15500]Recompensa promedio últimos episodios 50: 4.10
# [Episodio 15550]Recompensa promedio últimos episodios 50: 3.82
# [Episodio 15600]Recompensa promedio últimos episodios 50: 4.34
# [Episodio 15650]Recompensa promedio últimos episodios 50: 4.10
# [Episodio 15700]Recompensa promedio últimos episodios 50: 4.96
# [Episodio 15750]Recompensa promedio últimos episodios 50: 4.08
# [Episodio 15800]Recompensa promedio últimos episodios 50: 5.10
# [Episodio 15850]Recompensa promedio últimos episodios 50: 4.50
# [Episodio 15900]Recompensa promedio últimos episodios 50: 4.34
# [Episodio 15950]Recompensa promedio últimos episodios 50: 4.16
# [Episodio 16000]Recompensa promedio últimos episodios 50: 4.52
# [Episodio 16050]Recompensa promedio últimos episodios 50: 4.18
# [Episodio 16100]Recompensa promedio últimos episodios 50: 4.62
# [Episodio 16150]Recompensa promedio últimos episodios 50: 4.44
# [Episodio 16200]Recompensa promedio últimos episodios 50: 4.88
# [Episodio 16250]Recompensa promedio últimos episodios 50: 5.10
# [Episodio 16300]Recompensa promedio últimos episodios 50: 4.20
# [Episodio 16350]Recompensa promedio últimos episodios 50: 4.74
# [Episodio 16400]Recompensa promedio últimos episodios 50: 5.34
# [Episodio 16450]Recompensa promedio últimos episodios 50: 4.28
# [Episodio 16500]Recompensa promedio últimos episodios 50: 4.02
# Entrenamiento completo, modelo guardado dqn_battlezone_resume.zip
# MoviePy - Building video /mnt/disk/amlopeza/CancerLLMRes/code/dev/Microproyecto/DRL/Code/output_v2/rl-video-step-0-to-step-1000000.mp4.
# MoviePy - Writing video /mnt/disk/amlopeza/CancerLLMRes/code/dev/Microproyecto/DRL/Code/output_v2/rl-video-step-0-to-step-1000000.mp4
# MoviePy - Done !
# MoviePy - video ready /mnt/disk/amlopeza/CancerLLMRes/code/dev/Microproyecto/DRL/Code/output_v2/rl-video-step-0-to-step-1000000.mp4

# %%
monitor =  pd.read_csv('/content/logs_bzone/monitor.csv')

# %%
monitor.head()
